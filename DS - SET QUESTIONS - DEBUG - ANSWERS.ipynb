# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.DataFrame({
    'Experience': [1, 3, 5, 7, 10],
    'Projects': [2, 5, 8, 10, 12],
    'Performance': [3, 6, 7, 8, 9],
    'Department': ['HR', 'IT', 'Sales', 'IT', 'HR']
})

correlation_matrix = data.corr()
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %%
#ANSWER 1: 
#Answer: Correlation can be found for only int and float dtype
#Correct Code:
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.DataFrame({
    'Experience': [1, 3, 5, 7, 10],
    'Projects': [2, 5, 8, 10, 12],
    'Performance': [3, 6, 7, 8, 9],
    'Department': ['HR', 'IT', 'Sales', 'IT', 'HR']
})

correlation_matrix = data.corr(numeric_only = True)
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %%
import pandas as pd
import numpy as np

data = pd.DataFrame({
    'Name': ['John', 'Emily', 'Michael', 'kishor', 'Sarah'],
    'Age': [25, 30, np.nan, 28, 22],
    'Salary': [50000, 60000, 55000, 58000, np.nan]
})

data.fillna(np.mean, inplace=True)
data

# %%
#ANSWER 2: 
#Replace the np.nan and fill using the mean
#Correct Code
import pandas as pd
import numpy as np

data = pd.DataFrame({
    'Name': ['John', 'Emily', 'Michael', 'kishor', 'Sarah'],
    'Age': [25, 30, np.nan, 28, 22],
    'Salary': [50000, 60000, 55000, 58000, np.nan]
})
data.replace('np.nan', '',inplace = True)
data['Age'] = data['Age'].fillna(data['Age'].mean())
data['Salary'] = data['Salary'].fillna(data['Salary'].mean())
data
# Out:
#       Name    Age   Salary
# 0     John  25.00  50000.0
# 1    Emily  30.00  60000.0
# 2  Michael  26.25  55000.0
# 3   kishor  28.00  58000.0
# 4    Sarah  22.00  55750.0

# %% [markdown]
# from scipy import stats
#
# group1 = [120, 125, 130, 122, 128]
# group2 = [110, 115, 108, 102, 107]
#
# t_stat, p_value = stats.ttest_ind(group1, group2, axis=1)
# print(f"T-Statistic: {t_stat}, P-Value: {p_value}")
#
# if p_value <= 0.05:
#     print("Reject the null hypothesis: Significant difference.")
# else:
#     print("Fail to reject the null hypothesis: No significant difference.")

# %%
#ANSWER 3:
#Error: Module Name is Wrong and no axis parameter is needed
#Correct Code: 
from scipy import stats

group1 = [120, 125, 130, 122, 128]
group2 = [110, 115, 108, 102, 107]

t_stat, p_value = stats.f_oneway(group1, group2)
print(f"T-Statistic: {t_stat}, P-Value: {p_value}")

if p_value <= 0.05:
    print("Reject the null hypothesis: Significant difference.")
else:
    print("Fail to reject the null hypothesis: No significant difference.")
# Out:
# T-Statistic: 35.058524173027976, P-Value: 0.0003532844625064415
# Reject the null hypothesis: Significant difference.

# %% [markdown]
# import pandas as pd
# import numpy as np
#
# data = pd.DataFrame({'Salary': [30000, 32000, 34000, 500000, 36000, 37000, 39000, 41000, 42000, 450000]})
#
# outlier_threshold = data['Salary'].mean() + 3 * data['Salary'].std()
# outliers = data[data['Salary'] > outlier_threshold]
#
# print("Outliers:", outliers)

# %%
import pandas as pd
import numpy as np

data = pd.DataFrame({'Salary': [30000, 32000, 34000, 500000, 36000, 37000, 39000, 41000, 42000, 450000]})

outlier_threshold = data['Salary'].mean() + 3 * data['Salary'].std()
outliers = data[data['Salary'] > outlier_threshold]

print("Outliers:", outliers)
# Out:
# Outliers: Empty DataFrame
# Columns: [Salary]
# Index: []

# %%
#ANSWER 4:
#CORRECT CODE:
Q1 = data['Salary'].quantile(0.25)
Q3 = data['Salary'].quantile(0.75)
IQR = Q3 - Q1
IQR
#LOWER LIMIT
lower_limit = Q1 - 1.5 * IQR
lower_limit
#UPPER LIMIT
upper_limit = Q3 + 1.5 * IQR
upper_limit
#Outliers
outliers = data[(data['Salary']<lower_limit)|(data['Salary']>upper_limit)]
outliers
# Out:
#    Salary
# 3  500000
# 9  450000

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = np.random.normal(50, 10, 1000)

plt.hist()
plt.title("PDF Plot")
plt.show()

# %%
#ANSWER 5:
#Error: Data is not given
# Answer: data should be given as an argument inside the hist()
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = np.random.normal(50, 10, 1000)

sns.kdeplot(data)
plt.title("PDF Plot")
plt.show()
